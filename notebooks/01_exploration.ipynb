# %% [markdown]
# # Koreatown Sidewalk Accessibility Exploration
#
# Run the pipeline first with `python -m src.pipeline`, then use this notebook for quick inspection of generated layers and QA tables.

# %%
from pathlib import Path
import geopandas as gpd
import pandas as pd

base = Path('..') if Path.cwd().name == 'notebooks' else Path('.')
gpkg = base / 'outputs' / 'qgis' / 'koreatown_sidewalk_accessibility.gpkg'
labels = gpd.read_file(gpkg, layer='sidewalk_accessibility_labeled')
labels[['ai_label', 'accessibility_score', 'label_reason']].head()

# %%
pd.read_csv(base / 'outputs' / 'tables' / 'label_counts.csv')
